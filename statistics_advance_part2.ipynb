# %% [markdown]
# <center><h1>Theory</h1></center>

# %% [markdown]
# 1) **What is hypothesis testing in statistics?**
#
# Hypothesis testing method is used to make inferences or draw conculsion about a population based on data.It helps you assess whether there's enough evidence to support a specific claim or hypothesis about a population paramenter.
#
# **state the hypothesis**
#
# You start by formulating two competing hypotheses:
#
# **Null hypothesis (H₀):**
#
# This is the hypothesis that there is no effect or difference, or it represents a position of "no change." It's the default assumption.
#
# **Alternative hypothesis (H₁ or Ha)**:
#
# This represents the claim you're testing for, which suggests that there is an effect or difference.
#
# **Choose the Significance Level (α)**:
#
# This is the threshold for deciding whether the evidence is strong enough to reject the null hypothesis. Common values are 0.05 (5%) or 0.01 (1%)
#
# **Collect Data and Conduct the Test**:
#
# You gather your sample data and perform a statistical test (like a t-test, chi-square test, ANOVA, etc.) to analyze the data.
#
# **Calculate the p-value**:
#
# The p-value tells you how likely it is to observe your sample data, or something more extreme, if the null hypothesis is true. A small p-value (typically less than α) suggests that the null hypothesis is unlikely, leading to its rejection
#
# **Make a Decision: Based on the p-value:**
#
# If p-value ≤ α, reject the null hypothesis (there’s evidence to support the alternative hypothesis).
# If p-value > α, fail to reject the null hypothesis (there isn’t enough evidence to support the alternative hypothesis).
#
# **Draw a Conclusion**:
#
# Based on the decision, you either accept the alternative hypothesis or conclude that there's not enough evidence to reject the null hypothesis

# %% [markdown]
# 2) **what is significance level in hypothesis testing, and why it is imporant?**
#
# **What is the Significance Level?**
# The significance level is a pre-defined probability that represents the likelihood of rejecting the null hypothesis when it is actually true.
# Typically, α is set to 0.05, meaning you’re willing to accept a 5% chance of incorrectly rejecting the null hypothesis. Other common values for α include 0.01 (1%) or 0.10 (10%), depending on how stringent you want to be.
#
# **Why is it Important?**
#
# Control the Type I Error Rate:
#
# A Type I error occurs when you reject the null hypothesis even though it’s actually true (a false positive).
# The significance level α controls the probability of making this error. If you choose α = 0.05, for example, you're saying that you are willing to accept a 5% chance of making a Type I error.
# Helps Make Objective Decisions:
#
# The significance level sets a clear rule for decision-making. If the p-value from your test is smaller than α, you reject the null hypothesis. This helps ensure that decisions aren’t influenced by bias or subjectivity.
# Influences the Power of the Test:
#
# The significance level is closely related to the power of a statistical test, which is the probability of correctly rejecting the null hypothesis when it is false (avoiding a Type II error).
# A smaller α (say, 0.01) will make it harder to reject the null hypothesis, but it reduces the likelihood of a Type I error. However, this can also reduce the power of the test, making it harder to detect a true effect if one exists.
#
# **Example:**
# Imagine you're testing a new drug, and your null hypothesis is "The drug has no effect." You set α = 0.05:
#
# If your p-value is less than 0.05, you reject the null hypothesis and conclude that the drug has an effect (even though there could still be a small 5% chance that you’re wrong).
# If the p-value is greater than 0.05, you fail to reject the null hypothesis, suggesting there’s not enough evidence to support the claim that the drug has an effect.

# %% [markdown]
# 3) **what does p value represent in hypothesis testing?**
#
# In hypothesis testing, the p-value is a measure that helps you assess the strength of the evidence against the null hypothesis. It tells you how likely it is to observe the sample data—or something more extreme—if the null hypothesis is true.
#
# **What the p-value Represents:**
#
# The p-value represents the probability of getting results at least as extreme as the ones observed in your sample, assuming that the null hypothesis is correct.
#
# In simpler terms:
#
# **A small p-value** (typically less than the significance level, α) indicates strong evidence against the null hypothesis, suggesting that you should reject the null hypothesis.
# A large p-value suggests weak evidence against the null hypothesis, meaning you fail to reject it.
# Interpreting the p-value:
#
# **If p-value ≤ α (significance level):**
#
# You reject the null hypothesis (H₀).
# There’s enough evidence to support the alternative hypothesis (H₁).
# For example, with α = 0.05 and p = 0.03, since 0.03 < 0.05, you reject the null hypothesis.
#
# **If p-value > α (significance level):**
#
# You fail to reject the null hypothesis.
# There isn’t enough evidence to support the alternative hypothesis.
# For example, with α = 0.05 and p = 0.12, since 0.12 > 0.05, you fail to reject the null hypothesis.

# %% [markdown]
# 4) **How do you  interpret the p value in hypothesis testing?**
#
# Interpreting the p-value in hypothesis testing is crucial for drawing conclusions about your data. Here's how you can interpret it step by step:
#
# **1. Set the Significance Level (α)**
#
# Before conducting the test, you decide on the significance level (α), which is the threshold that determines how strong the evidence must be to reject the null hypothesis. Common choices for α are 0.05, 0.01, or 0.10.
#
# **2. Calculate the p-value**
#
# Once you have your data and you've chosen a test (like a t-test or chi-square test), you calculate the p-value. This value tells you how likely it is to observe the data you collected (or something more extreme) if the null hypothesis (H₀) is true.
#
# **3. Compare the p-value to α (the significance level)**
#
# If p-value ≤ α (p-value is smaller than or equal to the significance level):
#
# You reject the null hypothesis (H₀).
# Interpretation: The data provides enough evidence to support the alternative hypothesis (H₁). In other words, the observed result is unlikely to have occurred by random chance, suggesting a significant effect or difference.
# For example, if you set α = 0.05 and the p-value is 0.02, you reject H₀ and conclude that there is a statistically significant effect.
# If p-value > α (p-value is greater than the significance level):
#
# You fail to reject the null hypothesis.
# Interpretation: The data does not provide enough evidence to support the alternative hypothesis. The observed result is consistent with the null hypothesis, meaning any observed difference or effect could be due to random chance.
# For example, if α = 0.05 and the p-value is 0.10, you fail to reject H₀, suggesting there is no statistically significant effect.

# %% [markdown]
# 5) **what are the type 1 and type 2 errors in hyothesis testing?**
#
# **Type I Error (False Positive)**
# A Type I error occurs when you incorrectly reject the null hypothesis (H₀) when it is actually true. In other words, you conclude that there is an effect or difference when, in reality, there isn't.
#
# Example: Imagine you're testing a new drug to see if it has an effect on a disease. The null hypothesis (H₀) is that the drug has no effect. If you reject the null hypothesis and conclude that the drug does have an effect, even though it actually doesn't, you've made a Type I error.
#
# Probability of a Type I error: The probability of committing a Type I error is denoted by α (the significance level), typically set to 0.05. This means you're willing to accept a 5% chance of making a Type I error.
#
# Consequences: A Type I error leads you to believe there’s a significant effect or relationship when, in fact, there is none. This could lead to false conclusions, such as adopting ineffective treatments or making faulty business decisions.
#
# **2. Type II Error (False Negative)**
#
#
# A Type II error occurs when you fail to reject the null hypothesis (H₀) when it is actually false. In this case, you miss detecting a true effect or difference that exists.
#
# Example: Using the same drug test, the null hypothesis (H₀) is that the drug has no effect. If you fail to reject the null hypothesis and conclude that the drug has no effect, even though it actually does, you've made a Type II error.
#
# Probability of a Type II error: The probability of making a Type II error is denoted by β. The complement of β (1 − β) is called the power of the test, which is the probability of correctly rejecting the null hypothesis when it is false.
#
# Consequences: A Type II error means failing to detect a real effect. This could lead to missed opportunities, such as not recognizing a beneficial treatment or ignoring important trends.

# %% [markdown]
# 6) **What is diffrence between a one - tailed and two tailed test in hypothesis testing?**
#
# In hypothesis testing, the difference between a one-tailed and a two-tailed test lies in the direction of the test and what you are testing for.
#
# **One-tailed test:**
#
# A one-tailed test tests for the possibility of an effect in only one direction.
#
# It's used when you are interested in determining if the sample mean is significantly greater than or less than the population mean (but not both).
#
# For example, if you're testing if a new drug is more effective than an existing one, you would use a one-tailed test to test if the new drug's mean is greater than the existing one.
#
# Rejection region: All of the rejection region (where you reject the null hypothesis) is on one side of the distribution (either the left or the right, depending on the direction of the test).
#
# **Two-tailed test:**
#
# A two-tailed test tests for the possibility of an effect in both directions (either greater than or less than).
#
# It's used when you want to check if the sample mean is significantly different from the population mean in either direction (it could be either greater than or less than).
#
# For example, if you're testing whether a new drug has a different effect (could be more or less effective) compared to an existing one, you would use a two-tailed test.
#
# **Rejection region**: The rejection region is split between both tails of the distribution. If the test statistic falls in either of the extreme ends (either side of the distribution), you reject the null hypothesis.

# %% [markdown]
# 7) **What is z test and when is it used in hypothesis testing?**
#
# A z-test is a statistical test used to determine whether there is a significant difference between the means of two groups or whether a single group mean differs from a known value, based on a sample from the population.
#
# The z-test is based on the normal distribution and is typically used when the sample size is large (usually n>30) and/or the population standard deviation is known.
#
# When is a z-test used in hypothesis testing?
# A z-test is commonly used in the following scenarios:
#
# **Single Sample Mean (One-sample z-test):**
#
# When you're comparing the sample mean to a known population mean.
# Example: Is the average weight of apples in a sample different from the known population average of 150 grams?
#
# **Two Sample Means (Two-sample z-test):**
#
# When you're comparing the means of two independent samples (both samples come from normal populations with known standard deviations).
# Example: Do two different groups of students have the same average test scores?
# Proportions (Z-test for Proportions):
#
# When you're comparing proportions (like success rates) between groups.
# Example: Does the proportion of people who favor a new product differ between two regions?

# %% [markdown]
# 8) **How do you calculate the z-score and what does it represent in hypthesis testing?**
#
#
# To calculate a z-score, you use the following formula:
#
# $𝑧$ = $𝑋−𝜇$ $/𝜎$
#
# Where:
#
#
# X is the value you're evaluating,
#
# μ is the mean of the population,
#
# σ is the standard deviation of the population.
#
# In Hypothesis Testing:
# The z-score helps determine how far a sample statistic (like a sample mean) is from the population parameter (like the population mean) in terms of standard deviations.
#
# Here's how it connects to hypothesis testing:
#
# **Null Hypothesis (H0)**: This is the hypothesis that there is no effect or difference. For example, it might claim that the population mean is a certain value.
#
# **Alternative Hypothesis (HA)**: This is the hypothesis that contradicts the null hypothesis, suggesting a significant difference or effect.
#
# In hypothesis testing, the z-score helps you:
#
# Calculate the test statistic: It tells you how far your sample result is from the hypothesized population parameter.
# Determine significance: You compare the z-score to critical values from a standard normal distribution (based on your chosen significance level, usually 0.05). If the z-score exceeds the critical value, you reject the null hypothesis.
# For example, in a one-sample z-test:
#
# If the z-score is large (either positive or negative), it suggests that the sample mean is significantly different from the population mean, and you might reject the null hypothesis.
# If the z-score is close to zero, the sample mean is not significantly different from the population mean, so you fail to reject the null hypothesis.

# %% [markdown]
# 9) **What is T distribution ,and when how it is used in hypothisis testing?**
#
# The t-distribution (also called the Student’s t-distribution) is a type of probability distribution that is used in hypothesis testing when the sample size is small or when the population standard deviation is unknown.
#
# **Key Characteristics of the t-Distribution:**
# Shape: The t-distribution is bell-shaped and symmetric, just like the normal distribution, but it has heavier tails. This means that it accounts for more variability in the data, especially with smaller sample sizes.
#
# **Degrees of Freedom (df)**:
#
# The t-distribution is parameterized by the degrees of freedom (df), which depends on the sample size. For a sample of size 𝑛,the degrees of freedom is typically 𝑛−1 .The greater the degrees of freedom, the more the t-distribution resembles the normal distribution.Use in Small Samples: The t-distribution is used when the sample size is small (typically 𝑛<30) and the population standard deviation is unknown. If the sample size is large, the sample mean tends to follow a normal distribution due to the Central Limit Theorem, and the z-distribution can be used instead.
#
# **You calculate the t-statistic:**
#
# ![image.png](data:image/png;base64,...)
#
# Where:
# X is the sample mean,
#
# μ is the hypothesized population mean,
#
# s is the sample standard deviation,
#
# n is the sample size.

# %% [markdown]
# 10) **What is difference between z test and T test ?**
#
# Population Standard Deviation Known vs. Unknown:
#
# **Z-test:** Used when the population standard deviation (σ) is known. If the population standard deviation is known, the sample statistic can be standardized using the z-distribution.
#
# **T-test**: Used when the population standard deviation is unknown, and you are instead using the sample standard deviation (s) to estimate it.
#
# **Z-test**: Typically used when the sample size is large (generally 𝑛>30). With large samples, the sample mean approaches a normal distribution due to the Central Limit Theorem, so the z-test is appropriate.
#
# **T-test**: More commonly used for small sample sizes (typically 𝑛≤30), because the t-distribution accounts for the additional variability in estimating the population standard deviation from a small sample.

# %% [markdown]
# 11) **What is T test and how is it used in hypothesis testing?**
#
# How the T-test is Used in Hypothesis Testing:
# The t-test is used to assess whether there is enough evidence to reject the null hypothesis. Here's how it fits into the hypothesis testing process:
#
# **1. Formulate Hypotheses:**
# Null Hypothesis (h0): This is the default assumption that there is no effect or difference. For example, in a one-sample t-test, : the population mean equals a specific value.
# Alternative Hypothesis (𝐻𝐴): This is the hypothesis that suggests there is an effect or difference. For example,: the population mean is not equal to the hypothesized value.
#
# **2. Choose Significance Level (𝛼):**
# The significance level is typically set at 0.05, though other values like 0.01 or 0.10 can be used, depending on the field of study. This determines the probability of rejecting the null hypothesis when it is actually true (Type I error).
#
# **Calculate the Test Statistic (t-value):**
# The formula for the t-statistic varies slightly depending on the type of t-test, but the general form is:
#
#
# ![image.png](data:image/png;base64,...)
#
# Determine the Degrees of Freedom (df):
# Degrees of freedom (df) are needed to interpret the t-statistic. For a one-sample t-test, the degrees of freedom are calculated as:
#
# 𝑑𝑓 = 𝑛 − 1
#
# For a two-sample t-test, the degrees of freedom can be calculated using a more complex formula, depending on whether the variances of the two groups are assumed to be equal or unequal.

# %% [markdown]
# 12)**What is relationship between z-test and T-test in hypothesis testing?**
#
# The z-test and t-test are both used in hypothesis testing to assess if there is a significant difference between sample data and a population parameter (like the population mean). While they have similar goals and methods, they are used in different situations based on certain assumptions. Here's a breakdown of the relationship between them:
#
# **When to Use Z-test vs. T-test:**
#
# **Z-test:**
# Population standard deviation (σ) is known.
# Sample size is large (𝑛>30), so the sample mean is approximately normally distributed due to the Central Limit Theorem.
#
# **T-test:**
# Population standard deviation is unknown (you estimate it using the sample standard deviation, s).
# Sample size is small (𝑛≤30), and the sampling distribution of the mean is better approximated by the t-distribution (which accounts for more variability with small samples).

# %% [markdown]
# 13) **what is confidence interval,and how is it used to interpret statistical results?**
#
#
# A confidence interval (CI) is a range of values that is used to estimate an unknown population parameter (like a mean or proportion) based on sample data. It provides a range of plausible values for that parameter, along with a degree of confidence that the true parameter lies within that range.
#
# For example, a 95% confidence interval means that if you were to take 100 different samples and calculate the confidence interval for each one, approximately 95 of those intervals would contain the true population parameter.
#
# **Key Points:**
#
# **Range of Values**: The interval gives you a range (e.g., 50 to 60) within which the true parameter is likely to fall.
#
# **Confidence Level**: The confidence level (e.g., 95% or 99%) tells you how confident you can be that the interval contains the true population parameter. A higher confidence level means a wider interval.
#
# **Not a Guarantee**: A CI doesn't guarantee that the true value is in the range, just that, based on your sample data, you're X% confident that the true value lies in this range.

# %% [markdown]
# 14) **What is margin of error ,and how does it affect the confidence interval?**
#
#
# The margin of error (MOE) is a measure of the uncertainty or precision of an estimate from sample data. It represents the range within which the true population parameter (like the population mean or proportion) is expected to fall, considering the sample size and variability in the data.
#
# **Relationship with Confidence Interval:**
#
# The margin of error directly impacts the width of the confidence interval (CI). The CI is typically expressed as:
#
# CI = Estimate ± Margin of Error
#
# In other words, the margin of error defines how far the estimate might reasonably be from the true population parameter.
#
# How Margin of Error Affects Confidence Interval:
# Larger Margin of Error: The confidence interval will be wider. This means the estimate is less precise, and there’s greater uncertainty about where the true parameter lies. A wider interval reflects less confidence in the precision of the estimate.
#
# Smaller Margin of Error: The confidence interval will be narrower, indicating more precision and a higher level of certainty about where the true parameter is likely to be.

# %% [markdown]
# 15) **How is Bayes' Theorem used in statistics ,and what is its significant?**
#
#
# Bayes' Theorem is a fundamental concept in statistics that provides a way to update the probability of a hypothesis (or event) based on new evidence or data. It's a method of probabilistic inference, and it allows us to revise our beliefs or estimates as new information becomes available.
#
# **Formula for Bayes' Theorem:**
#
# The mathematical form of Bayes' Theorem is:
#
# ![images (2).png](data:image/png;base64,...)
#
# Where:
#
# P(A|B) is the posterior probability: the probability of event A occurring given that event B has occurred.
#
# P(B|A) is the likelihood: the probability of event B occurring given that event A has occurred.
#
# P(A) is the prior probability: the initial probability of event A before any evidence (or new data) is considered.
#
# P(B) is the marginal likelihood or normalizing constant: the probability of event B occurring, regardless of event A.
#
# **Dynamic and Flexible:** The power of Bayes' Theorem lies in its flexibility. It can be applied iteratively as new data comes in, making it ideal for dynamic systems and real-time decision-making.
#
# **Incorporating Prior Knowledge**: Unlike frequentist statistics, which often ignores prior information, Bayes’ approach allows the incorporation of prior knowledge, which can lead to more accurate predictions and decisions.
#
# **Probabilistic Interpretation**: Bayes’ Theorem offers a natural way to quantify uncertainty and update probabilities, which is valuable in many real-world applications like medical testing, fraud detection, and predictive modeling.

# %% [markdown]
# 16) **What is chai-square distribution ,when is it used?**
#
# The Chi-square distribution is a special case of the gamma distribution and arises when a normal distribution is squared. It has one parameter, called the degrees of freedom (df), which typically refers to the number of independent variables or observations involved in the test.
#
# The Chi-square distribution is right-skewed, especially for low degrees of freedom, and it becomes more symmetric as the degrees of freedom increase. The shape of the distribution depends heavily on the degrees of freedom.
#
# When is the Chi-Square Distribution Used?
# Goodness of Fit Tests: The Chi-square test is often used to assess how well a sample data fits a theoretical distribution. The most common example is the Chi-square goodness of fit test, which compares the observed frequency of events to the expected frequency under a given hypothesis. For example, if you're rolling a fair die, you expect each outcome (1 through 6) to appear with equal probability. A Chi-square test can help assess whether the observed outcomes match the expected ones.
#
# Test for Independence: The Chi-square test of independence is used to determine if two categorical variables are independent of each other. For example, you might use it to test if there is an association between gender and voting preference (e.g., do men and women vote for different political parties at different rates?). The test evaluates whether the observed distribution of frequencies in a contingency table matches the expected distribution if the two variables were independent.
#
# Homogeneity: A similar to the test for independence, the Chi-square test of homogeneity is used to determine whether different populations (or groups) have the same distribution of a categorical variable. For example, you might want to check if the distribution of preferences for a product is the same across different regions.
#
# Variance Testing: In some cases, the Chi-square distribution is also used to test hypotheses about the variance of a normally distributed population. For example, the Chi-square test for variance can help determine if the variance in a sample differs significantly from a hypothesized value.
#
# Key Points About the Chi-Square Test:
# Assumptions: The Chi-square test assumes that the data consists of independent observations. Also, the expected frequency in each cell of the contingency table should typically be at least 5 for the test to be valid.
#
# Degrees of Freedom: For a goodness of fit test, the degrees of freedom is typically the number of categories minus one. For tests of independence or homogeneity, it's determined by the number of rows and columns in the contingency table.

# %% [markdown]
# 17) **What is the chi-square of goodness of fit test and how is it applied?**
#
#
# The Chi-Square Goodness of Fit Test is a statistical test used to determine if there is a significant difference between the observed frequency distribution of a categorical variable and the expected frequency distribution based on a specific hypothesis.
#
# Steps to perform a Chi-Square Goodness of Fit Test:
# State the Hypotheses:
#
# Null Hypothesis (H₀): The observed frequencies match the expected frequencies (i.e., there is no significant difference).
# Alternative Hypothesis (H₁): The observed frequencies do not match the expected frequencies (i.e., there is a significant difference).
#
# **Compute the Chi-Square Statistic**:
# The Chi-Square statistic compares the difference between observed and expected frequencies. The formula is:
#
# ![chai square.png](data:image/png;base64,...)
#
# **Determine the Degrees of Freedom (df)**: The degrees of freedom for the test is typically the number of categories minus 1:
#
# df = 𝑘 − 1

# %% [markdown]
# 18) **What is the f distribution and when is it used?**
#
#
# The F-distribution is a probability distribution that arises in the context of variance analysis and is used primarily in hypothesis testing, particularly in analysis of variance (ANOVA) and regression analysis. It describes the ratio of two scaled chi-square distributions and is often used to compare variances between two or more groups.
#
# **Characteristics of the F-distribution:**
# Shape: The F-distribution is positively skewed, meaning it is not symmetric. Its shape is determined by two sets of degrees of freedom:
#
# **Numerator degrees of freedom (𝑑𝑓1)**: This is related to the variance of the group or sample whose variability is being tested.
#
# **Denominator degrees of freedom (𝑑𝑓2)**: This corresponds to the variability of the sample(s) or group(s) that are being compared.
# Non-negative: The F-distribution only takes values greater than or equal to 0 because it is based on the ratio of squared deviations (variances), which are always non-negative.
#
# Critical values: The F-distribution is used in hypothesis testing, and the critical value is determined by the degrees of freedom in both the numerator and denominator, as well as the chosen significance level (𝛼).

# %% [markdown]
# 19) **what is ANOVA Test , and what are its assumption?**
#
# The ANOVA (Analysis of Variance) test is a statistical technique used to compare the means of three or more groups to determine if there is a statistically significant difference among them. It helps to analyze whether the variation in a dataset can be attributed to different factors (such as treatment groups) or if it’s just due to random chance.
#
# **Assumption of ANNOVA:**
#
# The population from which samples are drown should be normally distributed.
#
# The sample should be independent of each other \random.
#
# Absence of outliers.
#
# Homogenity of variance : Homogenity means that the variance among the groups should be equal.

# %% [markdown]
# 20) **What is the F-test ,and does it relate to hypothesis testng?**
#
# F-test for Comparing Variances:
# When comparing two variances, the null hypothesis (H₀) is typically that the two population variances are equal. The alternative hypothesis (H₁) is that the variances are not equal.
#
# Null Hypothesis (H₀): The two population variances are equal.
#
#
# Alternative Hypothesis (H₁): The two population variances are not equal.
#
#
# F-statistic Formula for Variance Comparison:
# If you are comparing the variances of two independent groups (for example, variance in test scores between two groups), the F-statistic is calculated as the ratio of the two sample variances:
#
# Relation to Hypothesis Testing:
# The F-test is a type of hypothesis test, and it follows the typical framework for hypothesis testing:
#
# Null Hypothesis (H₀): The variances or models being compared are equal (or there is no significant difference).
# For example, in ANOVA: H₀: all group means are equal.
# Alternative Hypothesis (H₁): There is a significant difference between the variances or models.
# In ANOVA: H₁: at least one group mean is different.

# %% [markdown]
# 21) **What is null hypothesis , and how does it differ from the alternative hypothesis?**
#
# **Null Hypothesis (H₀):**
# The null hypothesis is a statement that there is no effect, no difference, or no relationship between variables. It is typically a statement that the researcher aims to test against. In other words, the null hypothesis assumes that any observed differences in a sample are due to random chance or sampling error, rather than a real effect.
#
# **Alternative Hypothesis (H₁ or Ha):**
# The alternative hypothesis is the opposite of the null hypothesis. It suggests that there is an effect, difference, or relationship between the variables being tested. It is the hypothesis that researchers typically hope to support, as it represents the potential new finding.

# %% [markdown]
# **What are different type of annova test?**
#
# **One way ANNOVA:** One factor with atleast two levels, and levels are independent.
#
# **Repeated measure ANNOVA:**
# one factor with atleast two levels but level are dependent.
#
# Factorial ANNOVA:
#  Two or more factors each of which with atleast two levels.levels can be either dependent ,independent or both

# %% [markdown]
# # **Practical Question**

# %% [markdown]
# 1)**Write a python program to perform a z - test for comparing a sample mean to a known population mean and interpret the result.**

# %%
import math
from scipy.stats import norm
def Z_test(sample_mean, population_mean,population_std, sample_size,alpha=0.05):
    z_score = (sample_mean - population_mean) / (population_std / math.sqrt(sample_size))
    z_critical = norm.ppf(1 - alpha/2)
    result =  abs(z_score) > z_critical
    if result:
        print("Reject the null hypothesis")
    else:
        print("we are fail to reject null hypothesis")
    return z_score, z_critical, result

# %%
Z_test(105,100,15,50)
# Out:
# Reject the null hypothesis
# (2.3570226039551585, 1.959963984540054, True)

# %% [markdown]
# 2) **simulate random data to perform hypothesis testing and calculate the corresponding p-value using python.**

# %%
import numpy as np
from scipy import stats
np.random.seed(0)
sample_size = 20
population_mean = 500
population_std = 15
sample = np.random.normal(loc=population_mean,scale=population_std,size=sample_size)
sample_mean = np.mean(sample)
sample_std = np.std(sample,ddof = 1)
t_statistic, p_value = stats.ttest_1samp(sample, population_mean)
alpha = 0.05
print(f"sample_mean:{sample_mean:.2f}")
print(f"sample_std:{sample_std:.2f}")
print(f"t_statistic:{t_statistic:.2f}")
print(f"p_value:{p_value:.4f}")
if p_value < alpha:
    result = "Reject the null hypothesis"
else:
    result = "fail to reject the null hypothesis"
print(result)
# Out:
# sample_mean:508.54
# sample_std:13.08
# t_statistic:2.92
# p_value:0.0088
# Reject the null hypothesis

# %% [markdown]
# 3) **Implement a one-sample Z-test using python and visualize the decision region on a plot**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
np.random.seed(0)
sample_size = 30
population_mean = 500
population_std = 15
sample = np.random.normal(loc = population_mean ,scale = population_std, size = sample_size)
sample_mean = np.mean(sample)
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
alpha = 0.05
z_critical = norm.ppf(1-alpha)
if abs(z_score) > z_critical:
    result = "Reject the null hypothesis"
else:
    result = "Fail to reject the null hypothesis"

print(f"sample_mean:{sample_mean:.2f}")
print(f"z_statistics:{z_score:.2f}")
print(f"z_critical z-value:{z_critical:2f}")
print(result)
x = np.linspace(-4, 4, 1000)
y = norm.pdf(x, 0, 1)
plt.figure(figsize=(8, 5))
plt.plot(x,y,label = "standard normal distribution",color = "blue")
plt.fill_between(x,y,0,where=(x < -z_critical) | (x > z_critical),color = 'red',alpha = 0.05,label = "Rejection region")
plt.axvline(z_score, color = 'green',linestyle = '--',label = f'z_stastics = {z_score:.2f}')
plt.title("One sample z_test:Decision region")
plt.xlabel("z_score")
plt.ylabel("Probability density")
plt.legend()
plt.show()
# Out:
# sample_mean:506.64
# z_statistics:2.43
# z_critical z-value:1.644854
# Reject the null hypothesis

# %% [markdown]
# 4) **Perform two-tail z-test using python and visualize the decision region on a plot**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
np.random.seed(0)
sample_size = 30
population_mean = 500
population_std = 15
sample = np.random.normal(loc = population_mean,scale = population_std,size = sample_size)
sample_mean = np.mean(sample)
z_score = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
alpha = 0.05
z_critical = norm.ppf(1-alpha/2)
if abs(z_score)>z_critical:
    result = "Reject the null hypothesis"
    color = "red"
else:
    result = "fail to reject the null hypothesis"
    color = "green"
print(f"sample_mean:{sample_mean:.2f}")
print(f"z_statistics:{z_score:2f}")
print(f"z_critical z-value:{z_score:.2f}")
print(result)
x = np.linspace(-4,4,100)
y = norm.pdf(x,0,1)
plt.figure(figsize = (8,6))
plt.plot(x,y,label="standard normal distribution",color = "blue")
plt.fill_between(x,y,0,where = (x < -z_critical) | (x > z_critical),color = "red",alpha = 0.05,label = "rejection region")
plt.axvline(z_score,color = "green",linestyle = "--",label = f"z_statistics = {z_score:.2f}")
plt.title("two tail z_test:Decision region")
plt.xlabel("z_score")
plt.ylabel("probability density")
plt.legend()
plt.show()
# Out:
# sample_mean:506.64
# z_statistics:2.425625
# z_critical z-value:2.43
# Reject the null hypothesis

# %% [markdown]
# 5) **Create a python function that calculates and visullizes type 1 and type 2 errors during hypothesis testing.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
def hypothesis_testing_with_errors(population_mean,population_std,sample_size,alpha,beta):
    sample_null = np.random.normal(loc = population_mean,scale = population_std,size = sample_size)
    sample_mean_null = np.mean(sample_null)
    sample_alternative = np.random.normal(loc = population_mean+5,scale = population_std,size = sample_size)
    sample_mean_alternative = np.mean(sample_alternative)
    z_score_null = (sample_mean_null - population_mean)/(population_std/np.sqrt(sample_size))
    z_score_alternative = (sample_mean_alternative - population_mean)/(population_std/np.sqrt(sample_size))
    z_critical_null = norm.ppf(1 - alpha)
    z_critical_alternative = norm.ppf(1-beta)
    type1_error_area = z_score_null>z_critical_null
    type2_error_area =  abs(z_score_alternative)<z_critical_alternative
    x = np.linspace(-4,4,100)
    y = norm.pdf(x,0,1)
    plt.figure(figsize = (8,6))
    plt.plot(x,y,0,label = "standard normal distribution",color = "blue")
    plt.fill_between(x,y,0,where = (x < -z_critical)| (x > z_critical),color = "red",alpha = 0.05,label = "rejection region")
    plt.axvline(z_score_null,color = "green",linestyle = "--",label = f"z_statistics (HO) = {z_score_null}")
    plt.axvline(z_score_alternative,color = "red",linestyle = "--",label = f"z_statistics (H1) = {z_score_alternative}")
    plt.title("Hypothesis Testing: Type I and Type II Errors")
    plt.xlabel("Z-Score")
    plt.ylabel("Probability Density")
    plt.legend()
    print(f"Sample Mean under H0: {sample_mean_null:.2f}")
    print(f"Z-Statistic under H0: {z_score_null:.2f}")
    print(f"Sample Mean under H1: {sample_mean_alternative:.2f}")
    print(f"Z-Statistic under H1: {z_score_alternative:.2f}")
    print(f"Type I Error (Reject H0 when H0 is true): {'Yes' if type1_error_area else 'No'}")
    print(f"Type II Error (Fail to reject H0 when H1 is true): {'Yes' if type2_error_area else 'No'}")
    plt.show()

# %%
hypothesis_testing_with_errors(population_mean=100, population_std=15, sample_size=30, alpha=0.05, beta=0.2)
# Out:
# Sample Mean under H0: 95.66
# Z-Statistic under H0: -1.59
# Sample Mean under H1: 102.99
# Z-Statistic under H1: 1.09
# Type I Error (Reject H0 when H0 is true): No
# Type II Error (Fail to reject H0 when H1 is true): No

# %% [markdown]
# 6) **Write a python program to perform an independent T-test and interpret the result.**

# %%
import numpy as np
from scipy import stats
group1 = [23, 21, 19, 24, 30, 32, 25, 26, 28, 22]
group2 = [15, 17, 16, 14, 18, 20, 19, 21, 23, 22]
t_stat, p_value = stats.ttest_ind(group1, group2)
print(f"T-statistic: {t_stat:.2f}")
print(f"p_value:{p_value:2f}")
alpha = 0.05
if p_value < alpha:
    print("The difference between the two groups is statistically significant.")
else:
    print("The difference between the two groups is not statistically significant.")
# Out:
# T-statistic: 4.04
# p_value:0.000761
# The difference between the two groups is statistically significant.

# %% [markdown]
# 7) **perform a paired sample T-test using python and visualize the comparison result.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
before_treatment = [200, 190, 180, 210, 215, 190, 185, 205, 200, 195]
after_treatment = [210, 200, 190, 220, 225, 195, 200, 210, 215, 205]
t_stat, p_value = stats.ttest_rel(before_treatment, after_treatment)
print(f"T-statistic: {t_stat}")
print(f"P-value: {p_value}")
alpha = 0.05
if p_value < alpha:
    print("The difference between before and after treatment is statistically significant.")
else:
    print("The difference between before and after treatment is not statistically significant.")
labels = ['Before', 'After']
data = [before_treatment, after_treatment]
plt.figure(figsize=(8,5))
plt.bar(labels,[np.mean(before_treatment), np.mean(after_treatment)],color=['blue', 'green'])
plt.errorbar(labels,[np.mean(before_treatment),np.mean(after_treatment)],yerr = [np.std(before_treatment),np.std(after_treatment)],fmt='o', color='black', capsize=5)
plt.title("Comparison of Before and After Treatment (Paired Sample)")
plt.ylabel("Values")
plt.show()
# Out:
# T-statistic: -9.486832980505138
# P-value: 5.537727791862317e-06
# The difference between before and after treatment is statistically significant.

# %% [markdown]
# 8) **simulate data and perform both z-test and T-test,then compare the results using python.**

# %%
import numpy as np
import scipy.stats as stats
np.random.seed(0)
sample_size = 30
population_mean = 500
population_std = 10
sample = np.random.normal(loc = population_mean, scale = population_std, size = sample_size)
sample_mean = np.mean(sample)
sample_std = np.std(sample,ddof =1)
z_stat = (sample_mean - population_mean) / (population_std / np.sqrt(sample_size))
z_p_value = stats.norm.sf(abs(z_stat))*2
t_statistic,t_p_value = stats.ttest_1samp(sample,population_mean)
print(f"z-test:z-statistic={z_stat:.4f},p-value = {z_p_value:.4f}")
print(f"T-test: t-statistic = {t_stat:.4f}, p-value = {t_p_value:.4f}")
if z_p_value < 0.05:
    print("z test:Reject the null hypothesis")
else:
    print("z test:fail to reject the null hypothesis")
if t_p_value < 0.05:
   print("T test:Reject the null hypothesis")
else:
   print("T test: fail to reject null hypothesis")
# Out:
# z-test:z-statistic=2.4256,p-value = 0.0153
# T-test: t-statistic = -9.4868, p-value = 0.0356
# z test:Reject the null hypothesis
# T test:Reject the null hypothesis

# %% [markdown]
# 9) **Write a python function to calculate the confidence interval for a sample mean  and explain its significance.**

# %%
import scipy.stats as stats
import numpy as np
def calculate_confidence_interval(sample,confidence_level = 0.95):
  sample_mean = np.mean(sample)
  sample_std = np.std(sample,ddof = 1)
  sample_size = len(sample)
  if sample_size > 30:
    critical_value = stats.norm.ppf(1-(1-confidence_level)/2)
  else:
    critical_value = stats.t.ppf(1-(1-confidence_level)/2,df = sample_size-1)
  margin_error = critical_value * (sample_std / np.sqrt(sample_size))
  lower_bound = sample_mean - margin_error
  upper_bound = sample_mean + margin_error
  return (lower_bound,upper_bound)
sample_data = [12, 15, 18, 14, 19, 22, 16, 21, 20, 18]
ci = calculate_confidence_interval(sample_data)
print(f"The 95% confidence interval for the sample mean is: {ci}")
# Out:
# The 95% confidence interval for the sample mean is: (15.20663919535756, 19.79336080464244)

# %% [markdown]
# 10) **Write a python program to calculate the margin of error for a given confidence level using sample data**

# %%
import numpy as np
import scipy.stats as stats
def calculate_margin_of_error(sample,confidence_level = 0.95):
  sample_mean = np.mean(sample)
  sample_std = np.std(sample,ddof = 1)
  sample_size = len(sample)
  if sample_size > 30:
    critical_value = stats.norm.ppf(1-(1-confidence_level)/2)
  else:
    critical_value = stats.t.ppf(1-(1-confidence_level)/2,df = sample_size -1)
  margin_error = critical_value * (sample_std / np.sqrt(sample_size))
  #lower_bound = sample_mean - margin_error
  #upper_bound = sample_mean + margin_error
  return (margin_error)
sample_data = [12,15,18,14,19,22,16,21,20,18]
ci = 0.95
margin_of_error = calculate_margin_of_error(sample_data,ci)
print(f"the margin of error for the {ci*100} % confidence level is: {margin_of_error}")
# Out:
# the margin of error for the 95.0 % confidence level is: 2.29336080464244

# %% [markdown]
# 11) **Implement a Bayesian inference method using Bayes' Theorem in python and explain the process.**

# %%
def bayesian_inference(prior,likelihood,false_positive,evidence):
  posterior = (likelihood * prior)/ evidence
  return posterior
def calculate_evidence(likelihood,prior,false_positive,prior_not_h):
  evidence = (likelihood * prior)+(false_positive * prior_not_h)
  return evidence
prior = 0.05
likelihood = 0.9
false_positive = 0.02
prior_not_h = 0.95

evidence = calculate_evidence(likelihood, prior, false_positive, prior_not_h)
posterior = bayesian_inference(prior, likelihood, false_positive, evidence)
print(f"{posterior:.4f}")
# Out:
# 0.7031

# %%
evidence = calculate_evidence(likelihood,prior,false_positive,prior_not_h)

# %%
posterior = bayesian_inference(prior,likelihood,false_positive,evidence)

# %% [markdown]
# 12) **Perform chi-square test for independence between two categorical variables in python?**

# %%
import scipy.stats as stats
import numpy as np
import pandas as pd
data = np.array([[20,30],
                [40,50]])
chi2_stat,p_value,dof,expected = stats.chi2_contingency(data)
print(f"Chi-square statistic:{chi2_stat}")
print(f"p_value statistic:{p_value}")
print(f"degree of freedom:{dof}")
print(f"expected frequencies:\n{expected}")
if p_value < 0.05:
  print("Their is significant relationship between the variables")
else:
  print("Their is no significant relationship between the variables")
# Out:
# Chi-square statistic:0.10953703703703699
# p_value statistic:0.7406718293017753
# degree of freedom:1
# expected frequencies:
# [[21.42857143 28.57142857]
#  [38.57142857 51.42857143]]
# Their is no significant relationship between the variables

# %% [markdown]
# 13) **Write a python program to calculate the expected frequencies for a chi-square test based on observed data.**

# %%
import numpy as np
def calculate_expected_frequencies(observed):
  row_totals = observed.sum(axis = 1)
  col_totals = observed.sum(axis = 0)
  grand_total = observed.sum()
  expected = np.outer(row_totals,col_totals)/grand_total
  return expected
observed = np.array([[20,30],[40,50]])
expected_frequencies = calculate_expected_frequencies(observed)
print("observed frequencies:\n ",observed)
print("\nexpected frequencies:\n",expected_frequencies)
# Out:
# observed frequencies:
#   [[20 30]
#  [40 50]]
#
# expected frequencies:
#  [[21.42857143 28.57142857]
#  [38.57142857 51.42857143]]

# %% [markdown]
# 14) **Perform a goodness of fit test using python to compare the observed data to an expected distribution**

# %%
import numpy as np
from scipy.stats import chisquare
observed = np.array([12, 10, 8, 9, 11, 10])
expected = np.array([10,10,10,10,10,10])
chi2_stat,p_value = chisquare(observed,expected)
print(f"chi-square statistic:{chi2_stat}")
print(f"p-value:{p_value}")
alpha = 0.05
if p_value < alpha:
  print("There is a significant difference between the observed and expected distributions (reject H0).")
else:
  print("There is no significant difference between the observed and expected distributions (fail to reject H0).")
# Out:
# chi-square statistic:1.0
# p-value:0.9625657732472964
# There is no significant difference between the observed and expected distributions (fail to reject H0).

# %% [markdown]
# 15) **Create a python script to simulate and visualize the chi-square distribution and discuss its characteristics.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2
df_values = [1, 2, 5, 10]
size = 10000
plt.figure(figsize=(10, 6))
for df in df_values:
  samples = np.random.chisquare(df,size)
  plt.hist(samples,bins = 50,density=True, alpha=0.6, label=f'df = {df}')
  x = np.linspace(0, max(samples), 1000)
  plt.plot(x, chi2.pdf(x, df), label=f'Theory (df = {df})', linestyle='dashed')
  plt.title('Chi-Square Distribution for Different Degrees of Freedom')
  plt.xlabel('Value')
  plt.ylabel('Density')
  plt.legend()
  plt.show()

# %% [markdown]
# 16 )**implement an f-test using python to compare the variances of two random samples.**

# %%
import numpy as np
import scipy.stats as stats
np.random.seed(0)
sample1 = np.random.normal(loc = 50,scale = 1,size = 100)
sample2 = np.random.normal(loc = 55,scale = 2,size = 100)
var1 = np.var(sample1,ddof=1)
var2 = np.var(sample2,ddof=2)
f_statistic = max(var1, var2) / min(var1, var2)
df1 = len(sample1)-1
df2 = len(sample2)-1
p_value = 1-stats.f.cdf(f_statistic,df1,df2)
alpha = 0.05
print(f"f-statistics:{f_statistic}")
print(f"p-value:{p_value}")
print(f"variance of sample 1 :{var1}")
print(f"variance of sample 2 :{var2}")
if p_value < alpha:
  print("Reject the null hypothesis")
else:
  print("fail to reject the null hypothesis")
# Out:
# f-statistics:4.258441784378094
# p-value:2.4447111002245947e-12
# variance of sample 1 :1.026087494156497
# variance of sample 2 :4.369533859543841
# Reject the null hypothesis

# %% [markdown]
# 17) **Write a python program to perform an ANOVA test to compare means between multiple groups and plot the result.**

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(0)
group1 = np.random.normal(loc = 5,scale = 1,size = 50)
group2 = np.random.normal(loc = 7,scale = 1.5,size = 50)
group3 = np.random.normal(loc = 6,scale = 1,size = 50)
f_statistic, p_value = stats.f_oneway(group1, group2, group3)
alpha = 0.05
print(f"F-statistic: {f_statistic}")
print(f"p-value: {p_value}")
if p_value < alpha:
  print("Reject the null hypothesis")
  print("There is a significant difference between the means of the groups")
else:
  print("Fail to reject the null hypothesis: There is no significant difference between the group means.")
data = [group1, group2, group3]
labels = ['Group 1', 'Group 2', 'Group 3']
plt.figure(figsize=(8, 6))
sns.boxplot(data=data)
plt.title('Box Plot of Group Means')
plt.ylabel('Values')
plt.show()
# Out:
# F-statistic: 31.017456952404693
# p-value: 5.777502034187676e-12
# Reject the null hypothesis
# There is a significant difference between the means of the groups

# %% [markdown]
# 18) **Write a python function to check the assumptions(normally,indepence,and equal evidence)for ANOVA**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from statsmodels.stats.diagnostic import het_breuschpagan
def check_anova_assumptions(data, groups):
  print("\nChecking Normality Assumption:")
  for group in data[groups].unique():
      group_data = data[data[groups] == group].iloc[:, 0]  # Assuming the dependent variable is the first column
      stat, p_value = stats.shapiro(group_data)
      print(f"Group: {group} | Shapiro-Wilk Test p-value: {p_value:.4f}")
      if p_value < 0.05:
          print(f"Warning: Group {group} does not follow a normal distribution (p-value < 0.05).")
      else:
          print(f"Group {group} is approximately normal (p-value >= 0.05).")

    # Visualize Normality (QQ plots)
  plt.figure(figsize=(12, 6))
  for i, group in enumerate(data[groups].unique(), 1):
    plt.subplot(1, len(data[groups].unique()), i)
    group_data = data[data[groups] == group].iloc[:, 0]
    stats.probplot(group_data, dist="norm", plot=plt)
    plt.title(f'QQ Plot: Group {group}')
    plt.tight_layout()
    plt.show()
  print("\nChecking Homogeneity of Variance Assumption:")
  group_data_list = [data[data[groups] == group].iloc[:, 0] for group in data[groups].unique()]
  stat, p_value = stats.levene(*group_data_list)
  print(f"Levene's Test p-value: {p_value:.4f}")
  if p_value < 0.05:
      print("Warning: Variances are significantly different across groups (p-value < 0.05).")
  else:
      print("Homogeneity of variances assumption holds (p-value >= 0.05).")

    # Independence (This assumption can't be formally tested directly, but can be checked through study design)
  print("\nIndependence Assumption:")
  print("Independence cannot be formally tested directly, but it depends on the study design. Ensure random sampling and no autocorrelation.")

    # Visualize the data distribution (Boxplot)
  plt.figure(figsize=(8, 6))
  sns.boxplot(x=groups, y=data.columns[0], data=data)
  plt.title('Boxplot to visualize group distributions')
  plt.show()

# %% [markdown]
# 19) **Perform a two way ANOVA test using python to study the interection between two fectors and visualize the result**s.

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import seaborn as sns
import matplotlib.pyplot as plt
np.random.seed(42)
data = {
    'Factor1': np.repeat(['A', 'B', 'C'], 20),
    'Factor2': np.tile(['X', 'Y'], 30),
    'Response': np.random.normal(loc=0, scale=1, size=60)
}
df = pd.DataFrame(data)
model = smf.ols('Response ~ C(Factor1) * C(Factor2)', data=df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
print("ANOVA Table:")
print(anova_table)
if anova_table['PR(>F)']['C(Factor1):C(Factor2)'] < 0.05:
    print("Interaction between Factor1 and Factor2 is significant.")
else:
    print("No significant interaction between Factor1 and Factor2.")
plt.figure(figsize=(8, 6))
sns.pointplot(x='Factor1', y='Response', hue='Factor2', data=df, dodge=True, markers=["o", "s"], linestyles=["-", "--"])
plt.title('Interaction Plot: Factor1 and Factor2')
plt.show()
plt.figure(figsize=(8, 6))
sns.boxplot(x='Factor1', y='Response', hue='Factor2', data=df)
plt.title('Boxplot of Response by Factor1 and Factor2')
plt.show()
# Out:
# ANOVA Table:
#                           sum_sq    df         F    PR(>F)
# C(Factor1)              0.580882   2.0  0.327679  0.722017
# C(Factor2)              0.006618   1.0  0.007466  0.931463
# C(Factor1):C(Factor2)   0.248382   2.0  0.140114  0.869575
# Residual               47.863345  54.0       NaN       NaN
# No significant interaction between Factor1 and Factor2.

# %% [markdown]
# 20) **Write a python program to visualise the F-distribution and discuss its use in hypothesis testing.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import f
df1 = 5
df2 = 10
x = np.linspace(0,5,1000)
y = f.pdf(x,df1,df2)
plt.figure(figsize=(8, 6))
plt.plot(x, y, label=f'F-distribution (df1={df1}, df2={df2})', color='blue')
plt.title(f"F-distribution with df1 = 5 and df2 = 10'")
plt.xlabel('F-statistic')
plt.ylabel('Probability Density')
plt.legend()
plt.grid(True)
plt.show()
print(f"\nThe F-distribution with df1={df1} and df2={df2} is right-skewed.")
print("In hypothesis testing, we use the F-distribution to determine the critical value")
print("for the F-statistic, which helps us assess whether the variance between the groups")
print("is significantly different from the variance within the groups.")
# Out:
# The F-distribution with df1=5 and df2=10 is right-skewed.
# In hypothesis testing, we use the F-distribution to determine the critical value
# for the F-statistic, which helps us assess whether the variance between the groups
# is significantly different from the variance within the groups.

# %% [markdown]
# 21) Perform a one way annova test in python and visualize the results with boxplots to compare group means.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
np.random.seed(42)
group_A = np.random.normal(loc=50, scale=10, size=30)
group_B = np.random.normal(loc=55, scale=10, size=30)
group_C = np.random.normal(loc=60, scale=10, size=30)
data = pd.DataFrame({
    'value': np.concatenate([group_A, group_B, group_C]),
    'group': ['A']*30 + ['B']*30 + ['C']*30
})
f_stat, p_value = stats.f_oneway(group_A, group_B, group_C)
print(f'ANOVA p-value: {p_value}')
if p_value < 0.05:
  print("There is a significant difference between the groups.")
else:
  print("There is no significant difference between the groups.")
plt.figure(figsize=(8, 6))
sns.boxplot(x='group', y='value', data=data)
plt.title('Comparison of Group Means')
plt.xlabel('Group')
plt.ylabel('Value')
plt.show()
# Out:
# ANOVA p-value: 2.1200748140507085e-05
# There is a significant difference between the groups.

# %% [markdown]
# 22) **Simulate random data from a normal distribution ,then perform hyphothisis testing to evaluate the means.**

# %%
import numpy as np
from scipy import stats
np.random.seed(42)
data1 = np.random.normal(loc=10, scale=2, size=100)
data2 = np.random.normal(loc=12, scale=2, size=100)
t_stat,p_value = stats.ttest_ind(data1,data2)
print(f"t-statistic: {t_stat}")
print(f"p-value: {p_value}")
alpha = 0.05
if p_value < alpha:
  print("reject the null hyphothesis")
  print("There is a significant difference between the means of the groups.")
else:
  print("fail to reject the null hypothesis")
  print("There is no significant difference between the means of the groups.")
# Out:
# t-statistic: -8.551459943248743
# p-value: 3.292961428703462e-15
# reject the null hyphothesis
# There is a significant difference between the means of the groups.

# %% [markdown]
# 23) **Perform a hypothesis test for population variance using chi-square distribution and interpret the result.**

# %%
import numpy as np
from scipy import stats
np.random.seed(42)
data = np.random.normal(loc=10,scale = 2,size = 100)
sample_variance = np.var(data,ddof = 1)
sigma_0_squared = 4
n = len(data)
alpha = 0.05
df = n - 1
chi_square_stat = (n-1)*sample_variance/sigma_0_squared
p_value = 1-stats.chi2.cdf(chi_square_stat,df)
critical_value_upper = stats.chi2.ppf(1 - alpha / 2, df)
critical_value_lower = stats.chi2.ppf(alpha / 2, df)
print(f"Sample Variance: {sample_variance}")
print(f"Chi-square Test Statistic: {chi_square_stat}")
print(f"Critical Values: Lower = {critical_value_lower}, Upper = {critical_value_upper}")
if chi_square_stat < critical_value_lower or chi_square_stat > critical_value_upper:
    print("Reject the null hypothesis: The population variance is significantly different from 4.")
else:
    print("Fail to reject the null hypothesis: The population variance is not significantly different from 4.")
# Out:
# Sample Variance: 3.29907957452064
# Chi-square Test Statistic: 81.65221946938584
# Critical Values: Lower = 73.36108019128368, Upper = 128.4219886438403
# Fail to reject the null hypothesis: The population variance is not significantly different from 4.

# %% [markdown]
# 24) **Write a python script to perform a z test for comparing properties between two datasets or groups.**

# %%
import numpy as np
from scipy import stats
np.random.seed(42)
group1 = np.random.normal(loc=50, scale=10, size=100)
group2 = np.random.normal(loc=55, scale=10, size=100)
alpha = 0.05
mean1 = np.mean(group1)
mean2 = np.mean(group2)
std1 = np.std(group1)
std2 = np.std(group2)
n1 = len(group1)
n2 = len(group2)
pooled_std = np.sqrt((std1**2 / n1) + (std2**2 / n2))
z_statistic = (mean1 - mean2) / pooled_std
p_value = 2 * (1 - stats.norm.cdf(abs(z_statistic)))
alpha = 0.05
print(f"Z-statistic: {z_statistic}")
print(f"P-value: {p_value}")
if p_value < alpha:
    print("Reject the null hypothesis: The means are significantly different.")
else:
    print("Fail to reject the null hypothesis: The means are not significantly different.")
# Out:
# Z-statistic: -4.778649223282382
# P-value: 1.764767641354581e-06
# Reject the null hypothesis: The means are significantly different.

# %% [markdown]
# 25) **Implement an F-test for compairing the variances of two datasets,then interpret and visualize the result.**

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
np.random.seed(42)
data1 = np.random.normal(loc=50, scale=10, size=100)
data2 = np.random.normal(loc=50, scale=20, size=100)
var1 = np.var(data1, ddof=1)
var2 = np.var(data2, ddof=1)
F_statistic = var1 / var2
df1 = len(data1) - 1
df2 = len(data2) - 1
p_value = 2 * min(stats.f.cdf(F_statistic, df1, df2), 1 - stats.f.cdf(F_statistic, df1, df2))
alpha = 0.05
print(f"Sample Variance 1: {var1}")
print(f"Sample Variance 2: {var2}")
print(f"F-statistic: {F_statistic}")
print(f"P-value: {p_value}")
if p_value < alpha:
    print("Reject the null hypothesis: The variances are significantly different.")
else:
    print("Fail to reject the null hypothesis: The variances are not significantly different.")
plt.figure(figsize = (8,6))
plt.subplot(1,2,1)
plt.hist(data1,alpha = 0.7 ,bins = 20,label = "dataset1",color = "blue")
plt.hist(data2,alpha = 0.7 ,bins = 20,label = "dataset2",color = "orange")
plt.legend()
plt.subplot(1,2,2)
plt.boxplot([data1, data2], labels=['Dataset 1', 'Dataset 2'],patch_artist=True)
plt.title("boxplots of Dataset 1 and Dataset 2")
plt.show()
# Out:
# Sample Variance 1: 82.476989363016
# Sample Variance 2: 363.79379882429987
# F-statistic: 0.226713565842967
# P-value: 1.6205546755717673e-12
# Reject the null hypothesis: The variances are significantly different.
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_27204\2408260379.py:28: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([data1, data2], labels=['Dataset 1', 'Dataset 2'],patch_artist=True)

# %% [markdown]
# 26) **Perform chisquare test for goodness of fit with simulated data and analyse the results.**

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
np.random.seed(42)
observed = np.random.choice([1, 2, 3, 4, 5, 6], size=1000, p=[1/6]*6)
observed_counts = np.array([np.sum(observed == i) for i in range(1, 7)])
expected_counts = np.array([1000 * (1/6)] * 6)
chi2_stat, p_value = stats.chisquare(observed_counts, expected_counts)
alpha = 0.05
print(f"Observed Frequencies: {observed_counts}")
print(f"Expected Frequencies: {expected_counts}")
print(f"Chi-square Statistic: {chi2_stat}")
print(f"P-value: {p_value}")
if p_value < alpha:
    print("Reject the null hypothesis: The observed frequencies are significantly different from the expected frequencies.")
else:
    print("Fail to reject the null hypothesis: The observed frequencies are not significantly different from the expected frequencies.")
labels = [1, 2, 3, 4, 5, 6]
plt.figure(figsize=(10, 6))
bar_width = 0.35
x = np.arange(len(labels))
plt.bar(x - bar_width/2, observed_counts, bar_width, label='Observed', color='blue')
plt.bar(x + bar_width/2, expected_counts, bar_width, label='Expected', color='orange')
plt.xlabel('Die Faces')
plt.ylabel('Frequency')
plt.title('Chi-Square Goodness of Fit: Observed vs Expected Frequencies')
plt.xticks(x, labels)
plt.legend()
plt.show()
# Out:
# Observed Frequencies: [187 159 157 182 151 164]
# Expected Frequencies: [166.66666667 166.66666667 166.66666667 166.66666667 166.66666667
#  166.66666667]
# Chi-square Statistic: 6.32
# P-value: 0.2763147695478045
# Fail to reject the null hypothesis: The observed frequencies are not significantly different from the expected frequencies.
